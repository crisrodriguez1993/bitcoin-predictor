# %%
# Conexión de Google Drive y definición de ruta del proyecto
from google.colab import drive
drive.mount('/content/drive')

PROJECT_ROOT = '/content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2'
print('PROJECT_ROOT =', PROJECT_ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# PROJECT_ROOT = /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2

# %%
# Clonar/sincronizar rama específica (dev) en Drive
from pathlib import Path

REPO_URL = 'https://github.com/crisrodriguez1993/bitcoin-predictor.git'
REPO_BRANCH = 'dev'  # Cambia aquí si luego deseas otra rama
project_path = Path(PROJECT_ROOT)

if not project_path.exists():
    project_path.mkdir(parents=True, exist_ok=True)

if not (project_path / '.git').exists():
    # %cd "{project_path.parent}"
    # !git clone --branch "{REPO_BRANCH}" --single-branch "{REPO_URL}" "{project_path.name}"
    print(f'Repositorio clonado en {project_path} (rama: {REPO_BRANCH})')
else:
    print('Repositorio ya existe. Sincronizando rama...')
    # !git -C "{project_path}" fetch --all --prune
    # !git -C "{project_path}" checkout "{REPO_BRANCH}"
    # !git -C "{project_path}" pull origin "{REPO_BRANCH}"
    print(f'Repositorio sincronizado en {project_path} (rama: {REPO_BRANCH})')
# Out:
# Repositorio ya existe. Sincronizando rama...
# Fetching origin
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'
# From https://github.com/crisrodriguez1993/bitcoin-predictor
#  * branch            dev        -> FETCH_HEAD
# Already up to date.
# Repositorio sincronizado en /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2 (rama: dev)

# %%
# Instalación base en Colab con validación de requirements.txt
from pathlib import Path

req_path = Path(PROJECT_ROOT) / 'requirements.txt'
print('Buscando:', req_path)

if req_path.exists():
    # !pip install -q -r "{req_path}"
    print('Dependencias instaladas desde requirements.txt')
else:
    print('No existe requirements.txt en PROJECT_ROOT.')
    print('Opciones:')
    print('1) Subir/sincronizar el repo a esa ruta de Drive')
    print('2) Clonar el repo desde GitHub en Colab')
    print('3) Instalar paquetes mínimos temporales')
    
    # Fallback mínimo para continuar hoy
    # !pip install -q pandas numpy scikit-learn matplotlib seaborn yfinance ccxt praw ta tensorflow transformers torch
# Out:
# Buscando: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/requirements.txt
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 108.5 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.3/147.3 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.3/189.3 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 86.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 29.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 91.3 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 89.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 76.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 18.8 MB/s eta 0:00:00
#   Building wheel for ta (setup.py) ... done
# Dependencias instaladas desde requirements.txt

# %%
# Crear estructura base del proyecto en Google Drive
from pathlib import Path

BASE_DIRS = [
    'configs',
    'data/bronze/market_data',
    'data/bronze/macro_data',
    'data/bronze/sentiment_data',
    'data/silver',
    'data/gold',
    'models',
    'notebooks',
    'reports/figures',
]

for rel_dir in BASE_DIRS:
    path = Path(PROJECT_ROOT) / rel_dir
    path.mkdir(parents=True, exist_ok=True)
    print(f'OK: {path}')

print('\nEstructura base creada correctamente.')
# Out:
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/configs
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/data/bronze/market_data
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/data/bronze/macro_data
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/data/bronze/sentiment_data
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/data/silver
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/data/gold
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/models
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/notebooks
# OK: /content/drive/MyDrive/01. USFQ/01. Maestría IA/12. Trabajo de Titulación/05. V2/reports/figures
#
# Estructura base creada correctamente.
